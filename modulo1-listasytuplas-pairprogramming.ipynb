# %%
#EJERCICIOS LISTAS
print("1.")
lista = [2, 4, 6, 8]
print(lista)
lista = lista*2
#lista = lista + lista
print(lista)

print("\n2.")
lista1 = [1, 2, 3]
lista2 = [4, 5, 6]
lista_suma = lista1 + lista2
print(lista_suma)

print("\n3.")
suma_total = sum(lista1)
print("Lista1 es",lista1)
print("Suma de los elementos de lista1 es ",suma_total)

print("\n4.")
print("El elemento máximo de la lista1 es",max(lista1))

print("\n5.")
print("La longitud elemento máximo de la lista1 es",len(lista1))

print("\n6.")
print("Lista suma  es",lista_suma)
print("La posisición del elemento 4 de lista suma es",lista_suma.index(4))

print("\n7.")
print("Lista es ",lista)
print("El elemento 8 en lista aparece ",lista.count(8),"veces")

print("\n8.")
print("Lista es ",lista)
print("La sublista con los elementos de indice 2 hasta 5 sin incluir de lista es ",lista[2:5])

print("\n9.")
print("Lista es ",lista)
print("El último elemento de lista usando índices negativos es",lista[-1])

print("\n10.")
print("Lista es ",lista)
print("El número de elementos de lista es", len(lista))
print("El último elemento de lista usando índices positivos",lista[len(lista)-1])
# Out:
# 1.
# [2, 4, 6, 8]
# [2, 4, 6, 8, 2, 4, 6, 8]
#
# 2.
# [1, 2, 3, 4, 5, 6]
#
# 3.
# Lista1 es [1, 2, 3]
# Suma de los elementos de lista1 es  6
#
# 4.
# El elemento máximo de la lista1 es 3
#
# 5.
# La longitud elemento máximo de la lista1 es 3
#
# 6.
# Lista suma  es [1, 2, 3, 4, 5, 6]
# La posisición del elemento 4 de lista suma es 3
#
# 7.
# Lista es  [2, 4, 6, 8, 2, 4, 6, 8]
# El elemento 8 en lista aparece  2 veces
#
# 8.
# Lista es  [2, 4, 6, 8, 2, 4, 6, 8]
# La sublista con los elementos de indice 2 hasta 5 sin incluir de lista es  [6, 8, 2]
#
# 9.
# Lista es  [2, 4, 6, 8, 2, 4, 6, 8]
# El último elemento de lista usando índices negativos es 8
#
# 10.
# Lista es  [2, 4, 6, 8, 2, 4, 6, 8]
# El número de elementos de lista es 8
# El último elemento de lista usando índices positivos 8
